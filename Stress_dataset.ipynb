# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('mkbhd.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1428 non-null   int64
#  1   Title       1421 non-null   object
#  2   Views       1421 non-null   object
#  3   Date        1421 non-null   object
#  4   Likes       1413 non-null   object
#  5   Duration    1421 non-null   object
#  6   Commments   1421 non-null   object
#  7   Link        1428 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 89.4+ KB

# %%
data.head(50)
# Out:
#     Unnamed: 0                                              Title  \
# 0            0                          YouTube Needs to Fix This
# 1            1                 The Electric Car Pre-Order Problem
# 2            2     Does Fast Charging ACTUALLY Ruin Your Battery?
# 3            3           "The Apple Studio Display is a Bad Deal"
# 4            4                 Mac Studio Review: Double Trouble!
# 5            5            iPad Air M1 Review: Don't Choose Wrong!
# 6            6       iPhone SE (2022) Review: Old Dog. New Trick.
# 7            7            NEW Mac Studio & Apple Event Reactions!
# 8            8       Dope Tech: Weirdest Earbuds I've Ever Tried!
# 9            9             Galaxy Tab S8 Ultra: A Monster Tablet!
# 10          10  Galaxy S22 Ultra Review: Separating from the P...
# 11          11          Galaxy S22 Review: The iPhone of Android!
# 12          12    On New Cybertruck Updates from Drone Footage...
# ...

# %%
data.shape[0]
# Out:
# 1428

# %%
dup = data[data["Title"].duplicated(keep= "first")]

# %%
dup
# Out:
#       Unnamed: 0             Title            Views          Date  \
# 251          251               NaN              NaN           NaN
# 252          252               NaN              NaN           NaN
# 253          253               NaN              NaN           NaN
# 254          254               NaN              NaN           NaN
# 255          255               NaN              NaN           NaN
# 402          402     Dear YouTube!  1,415,816 views  Jun 29, 2018
# 821          821               NaN              NaN           NaN
# 1114        1114  MKBHD Update 6.0     13,072 views  Jul 17, 2010
#
#              Likes Duration Commments                                     Link
# 251            NaN      NaN       NaN  youtube.com/watch?v=kOEXcMoh2II&pp=sAQB
# 252            NaN      NaN       NaN  youtube.com/watch?v=6oHrNuXPVck&pp=sAQB
# 253            NaN      NaN       NaN  youtube.com/watch?v=AjQ7CEeONb4&pp=sAQB
# ...

# %%
dup2 = data.query("Likes == '0 likes'")

# %%
dup2
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Title, Views, Date, Likes, Duration, Commments, Link]
# Index: []

# %%
#d = data.drop_duplicates(["Title","Views","Date","Likes","Duration","Commments","Link"], keep = "first", inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1428 entries, 0 to 1427
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1428 non-null   int64
#  1   Title       1421 non-null   object
#  2   Views       1421 non-null   object
#  3   Date        1421 non-null   object
#  4   Likes       1413 non-null   object
#  5   Duration    1421 non-null   object
#  6   Commments   1421 non-null   object
#  7   Link        1428 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 89.4+ KB

# %%
data.isnull().any()
# Out:
# Unnamed: 0    False
# Title          True
# Views          True
# Date           True
# Likes          True
# Duration       True
# Commments      True
# Link          False
# dtype: bool

# %%
data.dropna(subset = ['Title'], inplace = True) # Dropped by title

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1427
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1421 non-null   int64
#  1   Title       1421 non-null   object
#  2   Views       1421 non-null   object
#  3   Date        1421 non-null   object
#  4   Likes       1413 non-null   object
#  5   Duration    1421 non-null   object
#  6   Commments   1421 non-null   object
#  7   Link        1421 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 99.9+ KB

# %%
data["Likes"].fillna(value = 0, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1427
# Data columns (total 8 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1421 non-null   int64
#  1   Title       1421 non-null   object
#  2   Views       1421 non-null   object
#  3   Date        1421 non-null   object
#  4   Likes       1421 non-null   object
#  5   Duration    1421 non-null   object
#  6   Commments   1421 non-null   object
#  7   Link        1421 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 99.9+ KB

# %%
data.drop(columns = ["Unnamed: 0"], inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1427
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Title      1421 non-null   object
#  1   Views      1421 non-null   object
#  2   Date       1421 non-null   object
#  3   Likes      1421 non-null   object
#  4   Duration   1421 non-null   object
#  5   Commments  1421 non-null   object
#  6   Link       1421 non-null   object
# dtypes: object(7)
# memory usage: 88.8+ KB

# %%
data.drop(columns = ["Commments", "Link", "Title"], inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1427
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Views     1421 non-null   object
#  1   Date      1421 non-null   object
#  2   Likes     1421 non-null   object
#  3   Duration  1421 non-null   object
# dtypes: object(4)
# memory usage: 55.5+ KB

# %%
data
# Out:
#                 Views          Date          Likes Duration
# 0       435,998 views   Apr 1, 2022   52,217 likes     0:20
# 1     1,492,800 views  Mar 30, 2022   83,763 likes     0:20
# 2     2,923,457 views  Mar 25, 2022  174,602 likes     0:20
# 3     3,228,172 views  Mar 22, 2022  124,575 likes     0:20
# 4     3,022,613 views  Mar 18, 2022  120,729 likes     0:20
# ...               ...           ...            ...      ...
# 1423    130,044 views   Jan 1, 2009    1,592 likes     0:20
# 1424  4,640,300 views   Jan 1, 2009  234,631 likes     0:20
# 1425    179,533 views  Sep 15, 2008    2,644 likes     0:20
# 1426    175,876 views  May 30, 2008    2,198 likes     0:20
# 1427    781,563 views  Mar 28, 2008   17,546 likes     0:20
#
# [1421 rows x 4 columns]

# %%
data['Likes']=data['Likes'].str.replace('likes','')

# %%
data
# Out:
#                 Views          Date     Likes Duration
# 0       435,998 views   Apr 1, 2022   52,217      0:20
# 1     1,492,800 views  Mar 30, 2022   83,763      0:20
# 2     2,923,457 views  Mar 25, 2022  174,602      0:20
# 3     3,228,172 views  Mar 22, 2022  124,575      0:20
# 4     3,022,613 views  Mar 18, 2022  120,729      0:20
# ...               ...           ...       ...      ...
# 1423    130,044 views   Jan 1, 2009    1,592      0:20
# 1424  4,640,300 views   Jan 1, 2009  234,631      0:20
# 1425    179,533 views  Sep 15, 2008    2,644      0:20
# 1426    175,876 views  May 30, 2008    2,198      0:20
# 1427    781,563 views  Mar 28, 2008   17,546      0:20
#
# [1421 rows x 4 columns]

# %%
data['Likes']=data['Likes'].str.replace(',','')

# %%
data['Views']=data['Views'].str.replace(',','')

# %%
data['Views']=data['Views'].str.replace('views','')

# %%
data
# Out:
#          Views          Date    Likes Duration
# 0      435998    Apr 1, 2022   52217      0:20
# 1     1492800   Mar 30, 2022   83763      0:20
# 2     2923457   Mar 25, 2022  174602      0:20
# 3     3228172   Mar 22, 2022  124575      0:20
# 4     3022613   Mar 18, 2022  120729      0:20
# ...        ...           ...      ...      ...
# 1423   130044    Jan 1, 2009    1592      0:20
# 1424  4640300    Jan 1, 2009  234631      0:20
# 1425   179533   Sep 15, 2008    2644      0:20
# 1426   175876   May 30, 2008    2198      0:20
# 1427   781563   Mar 28, 2008   17546      0:20
#
# [1421 rows x 4 columns]

# %%
data["Duration"].unique()
# Out:
# array(['0:20', '33:14', '11:02', '13:48', '12:23', '15:06', '15:08',
#        '10:08', '20:41', '14:18', '12:22', '13:21', '13:33', '11:43',
#        '13:34', '14:20', '16:16', '15:45', '12:53', '13:02', '19:07',
#        '6:47', '10:26', '11:44', '3:04', '4:10', '2:23', '3:09', '1:50',
#        '10:23', '18:43', '10:04', '15:03', '7:33', '7:45', '9:01',
#        '16:49', '12:45', '8:59', '20:13', '7:51', '10:56', '10:33',
#        '5:20', '2:34', '3:30', '5:31', '3:42', '5:32', '2:53', '5:03',
#        '8:06', '4:30', '3:20', '2:29', '2:02', '0:06', '1:03', '2:43',
#        '1:25', '0:26', '3:07', '0:34', '0:44', '7:59', '3:47', '2:55',
#        '1:38', '1:09', '2:50', '1:45', '3:33', '3:52', '2:52', '5:28',
#        '0:24', '5:15', '0:11', '4:48', '4:17', '5:25', '0:04', '0:23',
#        '0:08', '0:16', '6:05', '0:25', '5:34', '0:07', '4:22', '0:18',
#        '2:58', '0:15'], dtype=object)

# %%
data[['Min','Sec']] = data['Duration'].str.split(':', expand = True)

# %%
data
# Out:
#          Views          Date    Likes Duration Min Sec
# 0      435998    Apr 1, 2022   52217      0:20   0  20
# 1     1492800   Mar 30, 2022   83763      0:20   0  20
# 2     2923457   Mar 25, 2022  174602      0:20   0  20
# 3     3228172   Mar 22, 2022  124575      0:20   0  20
# 4     3022613   Mar 18, 2022  120729      0:20   0  20
# ...        ...           ...      ...      ...  ..  ..
# 1423   130044    Jan 1, 2009    1592      0:20   0  20
# 1424  4640300    Jan 1, 2009  234631      0:20   0  20
# 1425   179533   Sep 15, 2008    2644      0:20   0  20
# 1426   175876   May 30, 2008    2198      0:20   0  20
# 1427   781563   Mar 28, 2008   17546      0:20   0  20
#
# [1421 rows x 6 columns]

# %%
data.drop(columns = ["Duration"], axis = 1, inplace = True)

# %%
data
# Out:
#          Views          Date    Likes Min Sec
# 0      435998    Apr 1, 2022   52217    0  20
# 1     1492800   Mar 30, 2022   83763    0  20
# 2     2923457   Mar 25, 2022  174602    0  20
# 3     3228172   Mar 22, 2022  124575    0  20
# 4     3022613   Mar 18, 2022  120729    0  20
# ...        ...           ...      ...  ..  ..
# 1423   130044    Jan 1, 2009    1592    0  20
# 1424  4640300    Jan 1, 2009  234631    0  20
# 1425   179533   Sep 15, 2008    2644    0  20
# 1426   175876   May 30, 2008    2198    0  20
# 1427   781563   Mar 28, 2008   17546    0  20
#
# [1421 rows x 5 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1427
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Views   1421 non-null   object
#  1   Date    1421 non-null   object
#  2   Likes   1413 non-null   object
#  3   Min     1421 non-null   object
#  4   Sec     1421 non-null   object
# dtypes: object(5)
# memory usage: 66.6+ KB

# %%
data.Min = data.Min.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1427
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Views   1421 non-null   object
#  1   Date    1421 non-null   object
#  2   Likes   1413 non-null   object
#  3   Min     1421 non-null   int32
#  4   Sec     1421 non-null   object
# dtypes: int32(1), object(4)
# memory usage: 61.1+ KB

# %%
data.Sec = data.Sec.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1427
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Views   1421 non-null   object
#  1   Date    1421 non-null   object
#  2   Likes   1413 non-null   object
#  3   Min     1421 non-null   int32
#  4   Sec     1421 non-null   int32
# dtypes: int32(2), object(3)
# memory usage: 55.5+ KB

# %%
data["Min"] = data["Min"] * 60

# %%
data
# Out:
#          Views          Date    Likes  Min  Sec
# 0      435998    Apr 1, 2022   52217     0   20
# 1     1492800   Mar 30, 2022   83763     0   20
# 2     2923457   Mar 25, 2022  174602     0   20
# 3     3228172   Mar 22, 2022  124575     0   20
# 4     3022613   Mar 18, 2022  120729     0   20
# ...        ...           ...      ...  ...  ...
# 1423   130044    Jan 1, 2009    1592     0   20
# 1424  4640300    Jan 1, 2009  234631     0   20
# 1425   179533   Sep 15, 2008    2644     0   20
# 1426   175876   May 30, 2008    2198     0   20
# 1427   781563   Mar 28, 2008   17546     0   20
#
# [1421 rows x 5 columns]

# %%
data.Min.unique()
# Out:
# array([   0, 1980,  660,  780,  720,  900,  600, 1200,  840,  960, 1140,
#         360,  180,  240,  120,   60, 1080,  420,  540,  480,  300])

# %%
data["Duration"] = data['Min'] + data['Sec']

# %%
data.head(50)
# Out:
#        Views          Date    Likes   Min  Sec  Duration
# 0    435998    Apr 1, 2022   52217      0   20        20
# 1   1492800   Mar 30, 2022   83763      0   20        20
# 2   2923457   Mar 25, 2022  174602      0   20        20
# 3   3228172   Mar 22, 2022  124575      0   20        20
# 4   3022613   Mar 18, 2022  120729      0   20        20
# 5   3199349   Mar 16, 2022  119164      0   20        20
# 6   2500390   Mar 14, 2022  111941      0   20        20
# 7   3057691    Mar 8, 2022  134085      0   20        20
# 8   2294404    Mar 2, 2022  114881      0   20        20
# 9   3608324   Feb 25, 2022  127157      0   20        20
# 10  3099938   Feb 22, 2022  114681      0   20        20
# 11  4101287   Feb 18, 2022  159759      0   20        20
# 12  1933244   Feb 16, 2022   89897      0   20        20
# 13  3197786    Feb 9, 2022  134746      0   20        20
# 14  2307433    Feb 9, 2022   94249      0   20        20
# ...

# %%
data.drop(columns = ["Min", "Sec"], axis = 1, inplace = True)

# %%
data
# Out:
#          Views          Date    Likes  Duration
# 0      435998    Apr 1, 2022   52217         20
# 1     1492800   Mar 30, 2022   83763         20
# 2     2923457   Mar 25, 2022  174602         20
# 3     3228172   Mar 22, 2022  124575         20
# 4     3022613   Mar 18, 2022  120729         20
# ...        ...           ...      ...       ...
# 1423   130044    Jan 1, 2009    1592         20
# 1424  4640300    Jan 1, 2009  234631         20
# 1425   179533   Sep 15, 2008    2644         20
# 1426   175876   May 30, 2008    2198         20
# 1427   781563   Mar 28, 2008   17546         20
#
# [1421 rows x 4 columns]

# %%
data["Likes"].fillna(value = 0, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1427
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Views     1421 non-null   object
#  1   Date      1421 non-null   object
#  2   Likes     1421 non-null   object
#  3   Duration  1421 non-null   int32
# dtypes: int32(1), object(3)
# memory usage: 50.0+ KB

# %%
data.Likes = data.Likes.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1421 entries, 0 to 1427
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Views     1421 non-null   object
#  1   Date      1421 non-null   object
#  2   Likes     1421 non-null   int32
#  3   Duration  1421 non-null   int32
# dtypes: int32(2), object(2)
# memory usage: 44.4+ KB

# %%
data.drop(data[data['Likes'] < 1].index, inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413 entries, 0 to 1427
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Views     1413 non-null   object
#  1   Date      1413 non-null   object
#  2   Likes     1413 non-null   int32
#  3   Duration  1413 non-null   int32
# dtypes: int32(2), object(2)
# memory usage: 44.2+ KB

# %%
data.Views = data.Views.astype(int)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413 entries, 0 to 1427
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Views     1413 non-null   int32
#  1   Date      1413 non-null   object
#  2   Likes     1413 non-null   int32
#  3   Duration  1413 non-null   int32
# dtypes: int32(3), object(1)
# memory usage: 38.6+ KB

# %%
data
# Out:
#         Views          Date   Likes  Duration
# 0      435998   Apr 1, 2022   52217        20
# 1     1492800  Mar 30, 2022   83763        20
# 2     2923457  Mar 25, 2022  174602        20
# 3     3228172  Mar 22, 2022  124575        20
# 4     3022613  Mar 18, 2022  120729        20
# ...       ...           ...     ...       ...
# 1423   130044   Jan 1, 2009    1592        20
# 1424  4640300   Jan 1, 2009  234631        20
# 1425   179533  Sep 15, 2008    2644        20
# 1426   175876  May 30, 2008    2198        20
# 1427   781563  Mar 28, 2008   17546        20
#
# [1413 rows x 4 columns]

# %%
data.Date.nunique()
# Out:
# 1287

# %%
data[["Month", "Year"]] = data['Date'].str.split(',', expand = True)

# %%
data
# Out:
#         Views          Date   Likes  Duration   Month   Year
# 0      435998   Apr 1, 2022   52217        20   Apr 1   2022
# 1     1492800  Mar 30, 2022   83763        20  Mar 30   2022
# 2     2923457  Mar 25, 2022  174602        20  Mar 25   2022
# 3     3228172  Mar 22, 2022  124575        20  Mar 22   2022
# 4     3022613  Mar 18, 2022  120729        20  Mar 18   2022
# ...       ...           ...     ...       ...     ...    ...
# 1423   130044   Jan 1, 2009    1592        20   Jan 1   2009
# 1424  4640300   Jan 1, 2009  234631        20   Jan 1   2009
# 1425   179533  Sep 15, 2008    2644        20  Sep 15   2008
# 1426   175876  May 30, 2008    2198        20  May 30   2008
# 1427   781563  Mar 28, 2008   17546        20  Mar 28   2008
#
# [1413 rows x 6 columns]

# %%
data.Month.unique()
# Out:
# array(['Apr 1', 'Mar 30', 'Mar 25', 'Mar 22', 'Mar 18', 'Mar 16',
#        'Mar 14', 'Mar 8', 'Mar 2', 'Feb 25', 'Feb 22', 'Feb 18', 'Feb 16',
#        'Feb 9', 'Feb 1', 'Jan 27', 'Jan 24', 'Jan 13', 'Jan 7', 'Jan 5',
#        'Jan 3', 'Dec 29', 'Dec 26', 'Dec 22', 'Dec 20', 'Dec 17',
#        'Dec 15', 'Dec 8', 'Dec 6', 'Dec 1', 'Nov 23', 'Nov 17', 'Nov 11',
#        'Nov 9', 'Nov 4', 'Nov 2', 'Oct 27', 'Oct 22', 'Oct 21', 'Oct 19',
#        'Oct 18', 'Oct 13', 'Oct 11', 'Oct 5', 'Oct 1', 'Sep 29', 'Sep 27',
#        'Sep 22', 'Sep 21', 'Sep 17', 'Sep 14', 'Sep 13', 'Sep 9',
#        'Aug 26', 'Aug 23', 'Aug 20', 'Aug 17', 'Aug 11', 'Aug 2',
#        'Jul 30', 'Jul 29', 'Jul 26', 'Jul 22', 'Jul 16', 'Jul 7', 'Jul 2',
#        'Jul 1', 'Jun 30', 'Jun 24', 'Jun 17', 'Jun 13', 'Jun 8', 'Jun 2',
#        'May 27', 'May 21', 'May 19', 'May 18', 'May 7', 'Apr 29',
#        'Apr 26', 'Apr 23', 'Apr 22', 'Apr 20', 'Apr 17', 'Apr 16',
# ...

# %%
data["Month"] = data["Month"].replace(['Premiered Dec 2','Streamed live on Nov 29', 'Streamed live on Oct 26', 'Streamed live on Sep 25', 'Streamed live on Sep 15' ], ["Dec 2", "Nov 29", "Oct 26", "Sep 25", "Sep 15"])

# %%
data.Month.unique()
# Out:
# array(['Apr 1', 'Mar 30', 'Mar 25', 'Mar 22', 'Mar 18', 'Mar 16',
#        'Mar 14', 'Mar 8', 'Mar 2', 'Feb 25', 'Feb 22', 'Feb 18', 'Feb 16',
#        'Feb 9', 'Feb 1', 'Jan 27', 'Jan 24', 'Jan 13', 'Jan 7', 'Jan 5',
#        'Jan 3', 'Dec 29', 'Dec 26', 'Dec 22', 'Dec 20', 'Dec 17',
#        'Dec 15', 'Dec 8', 'Dec 6', 'Dec 1', 'Nov 23', 'Nov 17', 'Nov 11',
#        'Nov 9', 'Nov 4', 'Nov 2', 'Oct 27', 'Oct 22', 'Oct 21', 'Oct 19',
#        'Oct 18', 'Oct 13', 'Oct 11', 'Oct 5', 'Oct 1', 'Sep 29', 'Sep 27',
#        'Sep 22', 'Sep 21', 'Sep 17', 'Sep 14', 'Sep 13', 'Sep 9',
#        'Aug 26', 'Aug 23', 'Aug 20', 'Aug 17', 'Aug 11', 'Aug 2',
#        'Jul 30', 'Jul 29', 'Jul 26', 'Jul 22', 'Jul 16', 'Jul 7', 'Jul 2',
#        'Jul 1', 'Jun 30', 'Jun 24', 'Jun 17', 'Jun 13', 'Jun 8', 'Jun 2',
#        'May 27', 'May 21', 'May 19', 'May 18', 'May 7', 'Apr 29',
#        'Apr 26', 'Apr 23', 'Apr 22', 'Apr 20', 'Apr 17', 'Apr 16',
# ...

# %%
data[["MonthR", "Day"]] = data['Month'].str.split(' ', expand = True)

# %%
data
# Out:
#         Views          Date   Likes  Duration   Month   Year MonthR Day
# 0      435998   Apr 1, 2022   52217        20   Apr 1   2022    Apr   1
# 1     1492800  Mar 30, 2022   83763        20  Mar 30   2022    Mar  30
# 2     2923457  Mar 25, 2022  174602        20  Mar 25   2022    Mar  25
# 3     3228172  Mar 22, 2022  124575        20  Mar 22   2022    Mar  22
# 4     3022613  Mar 18, 2022  120729        20  Mar 18   2022    Mar  18
# ...       ...           ...     ...       ...     ...    ...    ...  ..
# 1423   130044   Jan 1, 2009    1592        20   Jan 1   2009    Jan   1
# 1424  4640300   Jan 1, 2009  234631        20   Jan 1   2009    Jan   1
# 1425   179533  Sep 15, 2008    2644        20  Sep 15   2008    Sep  15
# 1426   175876  May 30, 2008    2198        20  May 30   2008    May  30
# 1427   781563  Mar 28, 2008   17546        20  Mar 28   2008    Mar  28
#
# [1413 rows x 8 columns]

# %%
data.drop(columns = ["Date", "Month"], axis = 1, inplace = True)

# %%
data
# Out:
#         Views   Likes  Duration   Year MonthR Day
# 0      435998   52217        20   2022    Apr   1
# 1     1492800   83763        20   2022    Mar  30
# 2     2923457  174602        20   2022    Mar  25
# 3     3228172  124575        20   2022    Mar  22
# 4     3022613  120729        20   2022    Mar  18
# ...       ...     ...       ...    ...    ...  ..
# 1423   130044    1592        20   2009    Jan   1
# 1424  4640300  234631        20   2009    Jan   1
# 1425   179533    2644        20   2008    Sep  15
# 1426   175876    2198        20   2008    May  30
# 1427   781563   17546        20   2008    Mar  28
#
# [1413 rows x 6 columns]

# %%
data.rename(columns = {'MonthR':'Month'}, inplace = True)

# %%
data
# Out:
#         Views   Likes  Duration   Year Month Day
# 0      435998   52217        20   2022   Apr   1
# 1     1492800   83763        20   2022   Mar  30
# 2     2923457  174602        20   2022   Mar  25
# 3     3228172  124575        20   2022   Mar  22
# 4     3022613  120729        20   2022   Mar  18
# ...       ...     ...       ...    ...   ...  ..
# 1423   130044    1592        20   2009   Jan   1
# 1424  4640300  234631        20   2009   Jan   1
# 1425   179533    2644        20   2008   Sep  15
# 1426   175876    2198        20   2008   May  30
# 1427   781563   17546        20   2008   Mar  28
#
# [1413 rows x 6 columns]

# %%
list(data)
# Out:
# ['Views', 'Likes', 'Duration', 'Year', 'Month', 'Day']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1413 entries, 0 to 1427
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Views     1413 non-null   int32
#  1   Likes     1413 non-null   int32
#  2   Duration  1413 non-null   int32
#  3   Year      1413 non-null   object
#  4   Month     1413 non-null   object
#  5   Day       1413 non-null   object
# dtypes: int32(3), object(3)
# memory usage: 60.7+ KB

# %%
data
# Out:
#         Views   Likes  Duration   Year Month Day
# 0      435998   52217        20   2022   Apr   1
# 1     1492800   83763        20   2022   Mar  30
# 2     2923457  174602        20   2022   Mar  25
# 3     3228172  124575        20   2022   Mar  22
# 4     3022613  120729        20   2022   Mar  18
# ...       ...     ...       ...    ...   ...  ..
# 1423   130044    1592        20   2009   Jan   1
# 1424  4640300  234631        20   2009   Jan   1
# 1425   179533    2644        20   2008   Sep  15
# 1426   175876    2198        20   2008   May  30
# 1427   781563   17546        20   2008   Mar  28
#
# [1413 rows x 6 columns]
